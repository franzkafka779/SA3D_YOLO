# %%
# !python run.py --config=configs/nerf_unbounded/Set1.py --stop_at=20000 --render_video --i_weights=10000
# !python run.py --config=configs/nerf_unbounded/Set2.py --stop_at=20000 --render_video --i_weights=10000
# !python run.py --config=configs/nerf_unbounded/Set3.py --stop_at=20000 --render_video --i_weights=10000
# !python run.py --config=configs/nerf_unbounded/Set4.py --stop_at=20000 --render_video --i_weights=10000
# !python run.py --config=configs/nerf_unbounded/Set5.py --stop_at=20000 --render_video --i_weights=10000
# !python run.py --config=configs/nerf_unbounded/Set6.py --stop_at=20000 --render_video --i_weights=10000
# !python run.py --config=configs/nerf_unbounded/Set7.py --stop_at=20000 --render_video --i_weights=10000
# !python run.py --config=configs/nerf_unbounded/Set8.py --stop_at=20000 --render_video --i_weights=10000
# !python run.py --config=configs/nerf_unbounded/Set9.py --stop_at=20000 --render_video --i_weights=10000
# !python run.py --config=configs/nerf_unbounded/Set10.py --stop_at=20000 --render_video --i_weights=10000
# !python run.py --config=configs/nerf_unbounded/Set11.py --stop_at=20000 --render_video --i_weights=10000
# !python run.py --config=configs/nerf_unbounded/Set12.py --stop_at=20000 --render_video --i_weights=10000
# !python run.py --config=configs/nerf_unbounded/Set13.py --stop_at=20000 --render_video --i_weights=10000
# Out:
# Using /home/lab/.cache/torch_extensions/py310_cu116 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/lab/.cache/torch_extensions/py310_cu116/render_utils_cuda/build.ninja...
# Building extension module render_utils_cuda...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ...

# %%
# !python run_seg_gui.py --config=configs/nerf_unbounded/seg_Set1.py --segment --sp_name=_gui --num_prompts=20 --render_opt=train --save_ckpt
# !python run_seg_gui.py --config=configs/nerf_unbounded/seg_Set2.py --segment --sp_name=_gui --num_prompts=20 --render_opt=train --save_ckpt
# !python run_seg_gui.py --config=configs/nerf_unbounded/seg_Set3.py --segment --sp_name=_gui --num_prompts=20 --render_opt=train --save_ckpt
# !python run_seg_gui.py --config=configs/nerf_unbounded/seg_Set4.py --segment --sp_name=_gui --num_prompts=20 --render_opt=train --save_ckpt
# !python run_seg_gui.py --config=configs/nerf_unbounded/seg_Set5.py --segment --sp_name=_gui --num_prompts=20 --render_opt=train --save_ckpt
# !python run_seg_gui.py --config=configs/nerf_unbounded/seg_Set6.py --segment --sp_name=_gui --num_prompts=20 --render_opt=train --save_ckpt
# !python run_seg_gui.py --config=configs/nerf_unbounded/seg_Set7.py --segment --sp_name=_gui --num_prompts=20 --render_opt=train --save_ckpt
# !python run_seg_gui.py --config=configs/nerf_unbounded/seg_Set8.py --segment --sp_name=_gui --num_prompts=20 --render_opt=train --save_ckpt
# !python run_seg_gui.py --config=configs/nerf_unbounded/seg_Set9.py --segment --sp_name=_gui --num_prompts=20 --render_opt=train --save_ckpt
# !python run_seg_gui.py --config=configs/nerf_unbounded/seg_Set10.py --segment --sp_name=_gui --num_prompts=20 --render_opt=train --save_ckpt
# !python run_seg_gui.py --config=configs/nerf_unbounded/seg_Set11.py --segment --sp_name=_gui --num_prompts=20 --render_opt=train --save_ckpt
# !python run_seg_gui.py --config=configs/nerf_unbounded/seg_Set12.py --segment --sp_name=_gui --num_prompts=20 --render_opt=train --save_ckpt
# !python run_seg_gui.py --config=configs/nerf_unbounded/seg_Set13.py --segment --sp_name=_gui --num_prompts=20 --render_opt=train --save_ckpt
# Out:
# Using /home/lab/.cache/torch_extensions/py310_cu116 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/lab/.cache/torch_extensions/py310_cu116/render_utils_cuda/build.ninja...
# Building extension module render_utils_cuda...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module render_utils_cuda...
# Using /home/lab/.cache/torch_extensions/py310_cu116 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/lab/.cache/torch_extensions/py310_cu116/total_variation_cuda/build.ninja...
# Building extension module total_variation_cuda...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module total_variation_cuda...
# ...

# %%
# !python run_seg_gui.py --config=configs/nerf_unbounded/seg_Set1.py --segment --sp_name=_gui --num_prompts=20 --render_only --render_opt=video --dump_images --seg_type seg_img seg_density
# !python run_seg_gui.py --config=configs/nerf_unbounded/seg_Set2.py --segment --sp_name=_gui --num_prompts=20 --render_only --render_opt=video --dump_images --seg_type seg_img seg_density
# !python run_seg_gui.py --config=configs/nerf_unbounded/seg_Set3.py --segment --sp_name=_gui --num_prompts=20 --render_only --render_opt=video --dump_images --seg_type seg_img seg_density
# !python run_seg_gui.py --config=configs/nerf_unbounded/seg_Set4.py --segment --sp_name=_gui --num_prompts=20 --render_only --render_opt=video --dump_images --seg_type seg_img seg_density
# !python run_seg_gui.py --config=configs/nerf_unbounded/seg_Set5.py --segment --sp_name=_gui --num_prompts=20 --render_only --render_opt=video --dump_images --seg_type seg_img seg_density
# !python run_seg_gui.py --config=configs/nerf_unbounded/seg_Set6.py --segment --sp_name=_gui --num_prompts=20 --render_only --render_opt=video --dump_images --seg_type seg_img seg_density
# !python run_seg_gui.py --config=configs/nerf_unbounded/seg_Set7.py --segment --sp_name=_gui --num_prompts=20 --render_only --render_opt=video --dump_images --seg_type seg_img seg_density
# !python run_seg_gui.py --config=configs/nerf_unbounded/seg_Set8.py --segment --sp_name=_gui --num_prompts=20 --render_only --render_opt=video --dump_images --seg_type seg_img seg_density
# !python run_seg_gui.py --config=configs/nerf_unbounded/seg_Set9.py --segment --sp_name=_gui --num_prompts=20 --render_only --render_opt=video --dump_images --seg_type seg_img seg_density
# !python run_seg_gui.py --config=configs/nerf_unbounded/seg_Set10.py --segment --sp_name=_gui --num_prompts=20 --render_only --render_opt=video --dump_images --seg_type seg_img seg_density
# !python run_seg_gui.py --config=configs/nerf_unbounded/seg_Set11.py --segment --sp_name=_gui --num_prompts=20 --render_only --render_opt=video --dump_images --seg_type seg_img seg_density
# !python run_seg_gui.py --config=configs/nerf_unbounded/seg_Set12.py --segment --sp_name=_gui --num_prompts=20 --render_only --render_opt=video --dump_images --seg_type seg_img seg_density
# !python run_seg_gui.py --config=configs/nerf_unbounded/seg_Set13.py --segment --sp_name=_gui --num_prompts=20 --render_only --render_opt=video --dump_images --seg_type seg_img seg_density
# Out:
# Using /home/lab/.cache/torch_extensions/py310_cu116 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/lab/.cache/torch_extensions/py310_cu116/render_utils_cuda/build.ninja...
# Building extension module render_utils_cuda...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module render_utils_cuda...
# Using /home/lab/.cache/torch_extensions/py310_cu116 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/lab/.cache/torch_extensions/py310_cu116/total_variation_cuda/build.ninja...
# Building extension module total_variation_cuda...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module total_variation_cuda...
# ...
